# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split

# %%
automobile = pd.read_csv('automobile_processed.csv')
automobile.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 331  12.0          8         455.0         225    4951          11.0   48
# 383  19.0          6         156.0         108    2930          15.5   45
# 391  34.3          4          97.0          78    2188          15.8   41
# 63   16.0          8         400.0         180    4220          11.1   44
# 52   25.0          4         140.0          92    2572          14.9   45

# %%
X = automobile[['horsepower']]
Y = automobile['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

#Normalization scales numerica features to be between 0  and 1.
#Having features in same scale can vastly improve performance of your ML model

linear_model = LinearRegression(normalize=True).fit(x_train,y_train)

# %%
#Score will return the R squared score  
print('Training Score : ', linear_model.score(x_train, y_train))
# Out:
# Training Score :  0.6088233750162888

# %%
y_pred = linear_model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print('Testing Score : ', r2_score(y_test, y_pred))
# Out:
# Testing Score :  0.5900848469790252

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Horsepower')
plt.ylabel('MPG')

plt.show()

# %%
X = automobile[['age']]
Y = automobile['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression(normalize=True).fit(x_train,y_train)


print('Training Score : ', linear_model.score(x_train, y_train))

y_pred = linear_model.predict(x_test)

print('Testing Score : ', r2_score(y_test, y_pred))
# Out:
# Training Score :  0.35841033358296737
# Testing Score :  0.19079079663692133

# %%
fig, ax = plt.subplots(figsize=(12,8))

plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')

plt.xlabel('Horsepower')
plt.ylabel('MPG')

plt.show()

# %% [markdown]
# <h1>Linear Regresson with Multiple Features

# %%
X = automobile[['displacement','horsepower','weight']]
Y = automobile['mpg']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training Score : ', linear_model.score(x_train, y_train))
# Out:
# Training Score :  0.7038806406599989

# %%
# y = Wx+B
#W = weights of coefficients of the model(model parameters)

predictors = x_train.columns

coef = pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# horsepower     -0.028045
# displacement   -0.010905
# weight         -0.005121
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
print('Testing Score',r2_score(y_test, y_pred))
# Out:
# Testing Score 0.7036709628100738

# %%
fig, ax = plt.subplots(figsize=(20,10))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()

# %%
X = automobile[['displacement','horsepower','weight','acceleration','cylinders']]
Y = automobile['mpg']

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
print('Training Score : ', linear_model.score(x_train, y_train))
# Out:
# Training Score :  0.7054908404072868

# %%
predictors = x_train.columns

coef = pd.Series(linear_model.coef_, predictors).sort_values()
print(coef)
# Out:
# cylinders      -0.136765
# horsepower     -0.062042
# acceleration   -0.049440
# weight         -0.004671
# displacement   -0.003489
# dtype: float64

# %%
y_pred = linear_model.predict(x_test)

# %%
print('Testing Score',r2_score(y_test, y_pred))
# Out:
# Testing Score 0.7029072436637858

# %%
fig, ax = plt.subplots(figsize=(20,10))

plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')

plt.ylabel('Mpg')

plt.legend()
plt.show()
